# %%
import openai

# %%
from openai import OpenAI

# %%
client = OpenAI()

# %%
response = client.chat.completions.create(model = 'gpt-3.5-turbo', 
                                          messages = [{'role':'user','content':'is it too late to join the course'}])

# %%
response.choices[0].message.content
# Out:
# "It depends on the course and the institution offering it. Some courses may have specific enrollment deadlines, while others may allow students to join at any time. It's best to contact the institution offering the course directly to inquire about enrollment opportunities."
